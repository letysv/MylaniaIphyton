# %%
# %run ../talktools.py
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Nixie+One' rel='stylesheet' type='text/css'>
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# #notebook_panel { /* main background */
#     background: rgb(245,245,245);
# }
#
# div.cell { /* set cell width */
#     width: 750px;
# }
#
# div #notebook { /* centre the content */
#     background: #fff; /* white background for content */
#     width: 1000px;
#     margin: auto;
#     padding-left: 0em;
# }
#
# #notebook li { /* More space between bullet points */
# margin-top:0.8em;
# }
#
# /* draw border around running cells */
# div.cell.border-box-sizing.code_cell.running {
#     border: 1px solid #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them*/
# div.cell.code_cell {
#     background-color: rgb(256,256,256);
#     border-radius: 0px;
#     padding: 0.5em;
#     margin-left:1em;
#     margin-top: 1em;
# }
#
# div.text_cell_render{
#     font-family: 'Alegreya Sans' sans-serif;
#     line-height: 140%;
#     font-size: 125%;
#     font-weight: 400;
#     width:600px;
#     margin-left:auto;
#     margin-right:auto;
# }
#
#
# /* Formatting for header cells */
# .text_cell_render h1 {
#     font-family: 'Nixie One', serif;
#     font-style:regular;
#     font-weight: 400;
#     font-size: 45pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.5em;
#     margin-top: 0.5em;
#     display: block;
# }
# .text_cell_render h2 {
#     font-family: 'Nixie One', serif;
#     font-weight: 400;
#     font-size: 30pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.1em;
#     margin-top: 0.3em;
#     display: block;
# }
#
# .text_cell_render h3 {
#     font-family: 'Nixie One', serif;
#     margin-top:16px;
# 	font-size: 22pt;
#     font-weight: 600;
#     margin-bottom: 3px;
#     font-style: regular;
#     color: rgb(102,102,0);
# }
#
# .text_cell_render h4 {    /*Use this for captions*/
#     font-family: 'Nixie One', serif;
#     font-size: 14pt;
#     text-align: center;
#     margin-top: 0em;
#     margin-bottom: 2em;
#     font-style: regular;
# }
#
# .text_cell_render h5 {  /*Use this for small titles*/
#     font-family: 'Nixie One', sans-serif;
#     font-weight: 400;
#     font-size: 16pt;
#     color: rgb(163,0,0);
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.8em;
#     display: block;
# }
#
# .text_cell_render h6 { /*use this for copyright note*/
#     font-family: 'PT Mono', sans-serif;
#     font-weight: 300;
#     font-size: 9pt;
#     line-height: 100%;
#     color: grey;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .CodeMirror{
#         font-family: "PT Mono";
#         font-size: 90%;
# }
#
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"],
#                            equationNumbers: { autoNumber: "AMS", useLabelIds: true}
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %%
import pandas as pd
# %matplotlib inline

# %%
archivo = '../files/VR07_11M.xls'
pd.read_excel(archivo).head()
# Out:
#              Estación:   XALAPAob        VER  Unnamed: 3  Unnamed: 4  \
# 0         Operada por:  SMN ESIME        NaN         NaN         NaN
# 1            Longitud:  96°54'14"  Longitud:    19°30'43    Altitud:
# 2                  NaN        NaN        NaN         NaN         NaN
# 3                FECHA       DIRS       DIRR  RAPVIENTO2  RAPRAFAGA2
# 4  2014-11-06 15:00:00        284        360         1.1         2.1
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0        NaN        NaN        NaN        NaN        NaN
# 1       1360        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN
# 3       TEMP         HR         PB       PREC    RAD-SOL
# 4       19.5         71      870.5          0        249

# %%
pd.read_excel(archivo, header=4).head()
# Out:
#                 FECHA  DIRS  DIRR  RAPVIENTO2  RAPRAFAGA2  TEMP  HR     PB  \
# 0 2014-11-06 15:00:00   284   360         1.1         2.1  19.5  71  870.5
# 1 2014-11-06 15:10:00   269    56         1.1         2.3  20.1  67  870.5
# 2 2014-11-06 15:20:00   227   300         0.9         2.0  21.0  62  870.6
# 3 2014-11-06 15:30:00    33   209         0.6         1.6  21.3  60  870.7
# 4 2014-11-06 15:40:00    22   200         0.8         2.5  21.4  65  870.8
#
#    PREC  RAD-SOL
# 0     0      249
# 1     0      386
# 2     0      377
# 3     0      307
# 4     0      368

# %%
pd.read_excel(archivo, header=4, index_col='FECHA').head()
# Out:
#                      DIRS  DIRR  RAPVIENTO2  RAPRAFAGA2  TEMP  HR     PB  \
# FECHA
# 2014-11-06 15:00:00   284   360         1.1         2.1  19.5  71  870.5
# 2014-11-06 15:10:00   269    56         1.1         2.3  20.1  67  870.5
# 2014-11-06 15:20:00   227   300         0.9         2.0  21.0  62  870.6
# 2014-11-06 15:30:00    33   209         0.6         1.6  21.3  60  870.7
# 2014-11-06 15:40:00    22   200         0.8         2.5  21.4  65  870.8
#
#                      PREC  RAD-SOL
# FECHA
# 2014-11-06 15:00:00     0      249
# 2014-11-06 15:10:00     0      386
# 2014-11-06 15:20:00     0      377
# 2014-11-06 15:30:00     0      307
# 2014-11-06 15:40:00     0      368

# %%
xalapaOb =pd.read_excel(archivo, header=4, index_col='FECHA', parse_dates=True, encoding='utf-8')
xalapaOb.head()
# Out:
#                      DIRS  DIRR  RAPVIENTO2  RAPRAFAGA2  TEMP  HR     PB  \
# FECHA
# 2014-11-06 15:00:00   284   360         1.1         2.1  19.5  71  870.5
# 2014-11-06 15:10:00   269    56         1.1         2.3  20.1  67  870.5
# 2014-11-06 15:20:00   227   300         0.9         2.0  21.0  62  870.6
# 2014-11-06 15:30:00    33   209         0.6         1.6  21.3  60  870.7
# 2014-11-06 15:40:00    22   200         0.8         2.5  21.4  65  870.8
#
#                      PREC  RAD-SOL
# FECHA
# 2014-11-06 15:00:00     0      249
# 2014-11-06 15:10:00     0      386
# 2014-11-06 15:20:00     0      377
# 2014-11-06 15:30:00     0      307
# 2014-11-06 15:40:00     0      368

# %%
xalapaOb.columns
# Out:
# Index([u'DIRS', u'DIRR', u'RAPVIENTO2', u'RAPRAFAGA2', u'TEMP', u'HR', u'PB', u'PREC', u'RAD-SOL'], dtype='object')

# %%
xalapaOb.columns[0]
# Out:
# u'DIRS'

# %%
xalapaOb.columns[0].strip()
# Out:
# u'DIRS'

# %%
xalapaOb[[u'      TEMP']].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-7ede23ec888c> in <module>()
# ----> 1 xalapaOb[[u'      TEMP']].head()
#
# C:\Users\Lety\Anaconda\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1670         if isinstance(key, (Series, np.ndarray, list)):
#    1671             # either boolean or fancy integer index
# -> 1672             return self._getitem_array(key)
#    1673         elif isinstance(key, DataFrame):
#    1674             return self._getitem_frame(key)
#
# C:\Users\Lety\Anaconda\lib\site-packages\pandas\core\frame.pyc in _getitem_array(self, key)
#    1714             return self.take(indexer, axis=0, convert=False)
#    1715         else:
# -> 1716             indexer = self.ix._convert_to_indexer(key, axis=1)
#    1717             return self.take(indexer, axis=1, convert=True)
#    1718
#
# C:\Users\Lety\Anaconda\lib\site-packages\pandas\core\indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter)
#    1083                     if isinstance(obj, tuple) and is_setter:
#    1084                         return {'key': obj}
# -> 1085                     raise KeyError('%s not in index' % objarr[mask])
#    1086
#    1087                 return indexer
#
# KeyError: "[u'      TEMP'] not in index"

# %% [markdown]
# NOS MARCA UN ERROR POR QUE TEMP NO EXISTE CON EL ESPACIO QUE TIENE

# %%
xalapaOb[['TEMP']]
# Out:
#                      TEMP
# FECHA
# 2014-11-06 15:00:00  19.5
# 2014-11-06 15:10:00  20.1
# 2014-11-06 15:20:00  21.0
# 2014-11-06 15:30:00  21.3
# 2014-11-06 15:40:00  21.4
# 2014-11-06 15:50:00  21.6
# 2014-11-06 16:00:00  20.9
# 2014-11-06 16:10:00  21.4
# 2014-11-06 16:20:00  21.4
# 2014-11-06 16:30:00  21.6
# 2014-11-06 16:40:00  21.1
# 2014-11-06 16:50:00  21.8
# 2014-11-06 17:00:00  22.8
# 2014-11-06 17:10:00  22.2
# 2014-11-06 17:20:00  22.2
# 2014-11-06 17:30:00  22.2
# 2014-11-06 17:40:00  22.1
# 2014-11-06 17:50:00  22.5
# 2014-11-06 18:00:00  22.5
# 2014-11-06 18:10:00  22.2
# 2014-11-06 18:20:00  23.5
# 2014-11-06 18:30:00  24.2
# 2014-11-06 18:40:00  23.3
# 2014-11-06 18:50:00  23.5
# 2014-11-06 19:00:00  22.8
# 2014-11-06 19:10:00  24.0
# 2014-11-06 19:20:00  24.6
# 2014-11-06 19:30:00  23.5
# 2014-11-06 19:40:00  22.5
# 2014-11-06 19:50:00  23.9
# ...                   ...
# 2014-11-07 10:00:00  15.5
# 2014-11-07 10:10:00  15.4
# 2014-11-07 10:20:00  15.4
# 2014-11-07 10:30:00  15.5
# 2014-11-07 10:40:00  15.4
# 2014-11-07 10:50:00  15.4
# 2014-11-07 11:00:00  15.4
# 2014-11-07 11:10:00  15.4
# 2014-11-07 11:20:00  15.5
# 2014-11-07 11:30:00  15.6
# 2014-11-07 11:40:00  15.6
# 2014-11-07 11:50:00  15.7
# 2014-11-07 12:00:00  15.8
# 2014-11-07 12:10:00  15.8
# 2014-11-07 12:20:00  15.8
# 2014-11-07 12:30:00  15.9
# 2014-11-07 12:40:00  15.9
# 2014-11-07 12:50:00  15.9
# 2014-11-07 13:00:00  16.0
# 2014-11-07 13:10:00  16.1
# 2014-11-07 13:20:00  16.3
# 2014-11-07 13:30:00  16.3
# 2014-11-07 13:40:00  16.3
# 2014-11-07 13:50:00  16.4
# 2014-11-07 14:00:00  16.8
# 2014-11-07 14:10:00  17.2
# 2014-11-07 14:20:00  17.4
# 2014-11-07 14:30:00  17.6
# 2014-11-07 14:40:00  18.0
# 2014-11-07 14:50:00   NaN
#
# [144 rows x 1 columns]

# %% [markdown]
# YA EJECUTA LA INSTRUCCION CON EXITO POR QUE YA SE LE PUSO TEMP SIN EL ESPACIO

# %%
xalapaOb.rename(columns=lambda x: x[:].strip(), inplace=True)
xalapaOb.rename(columns = {'RAD-SOL':'RADSOL'}, inplace=True)
xalapaOb.columns
# Out:
# Index([u'DIRS', u'DIRR', u'RAPVIENTO2', u'RAPRAFAGA2', u'TEMP', u'HR', u'PB', u'PREC', u'RADSOL'], dtype='object')

# %%
CustomPlot()
xalapaOb.plot()

# %%
xalapaOb.mean()
# Out:
# DIRS          153.846154
# DIRR          223.923077
# RAPVIENTO2      1.227972
# RAPRAFAGA2      2.619580
# TEMP           18.377622
# HR             88.419580
# PB            869.245455
# PREC            0.000000
# RADSOL        159.041958
# dtype: float64

# %%
xalapaOb.mean().plot(kind='bar')

# %%
figsize(11.5, 6)
font_size = 20
plt.title('Temperatura en Xalapa (24 horas)',fontsize = font_size)
plt.xlabel('hora',fontsize = font_size)
plt.ylabel(r'Temperatura [$^\circ C$] ',fontsize = font_size)
xalapaOb['TEMP'].plot();

# %%
figsize(11.5, 6)
font_size = 20
plt.title( 'Radiacion solar', fontsize=font_size)
plt.xlabel('horac', fontsize = font_size)
plt.ylabel(r'$MJ / day / m^2$',fontsize = font_size)
xalapaOb.RADSOL.plot();

# %%
xalapaOb.index
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2014-11-06 15:00:00, ..., 2014-11-07 14:50:00]
# Length: 144, Freq: None, Timezone: None

# %%
madrugada = xalapaOb['2014-11-07 3:00:00' : '2014-11-07 6:00:00']
madrugada.TEMP.head()
# Out:
# FECHA
# 2014-11-07 03:00:00    17.2
# 2014-11-07 03:10:00    17.3
# 2014-11-07 03:20:00    17.3
# 2014-11-07 03:30:00    17.1
# 2014-11-07 03:40:00    16.9
# Name: TEMP, dtype: float64

# %%
media = xalapaOb.TEMP.mean()
media
# Out:
# 18.377622377622377

# %%
madrugada[madrugada.TEMP <= media].head()
# Out:
#                      DIRS  DIRR  RAPVIENTO2  RAPRAFAGA2  TEMP  HR     PB  \
# FECHA
# 2014-11-07 03:00:00    98   201         0.6         1.5  17.2  98  870.5
# 2014-11-07 03:10:00    93   145         1.3         2.4  17.3  98  870.6
# 2014-11-07 03:20:00   105   180         1.0         2.2  17.3  97  870.6
# 2014-11-07 03:30:00    44   127         0.6         1.5  17.1  97  870.6
# 2014-11-07 03:40:00     0     0         0.0         0.0  16.9  98  870.5
#
#                      PREC  RADSOL
# FECHA
# 2014-11-07 03:00:00     0      -1
# 2014-11-07 03:10:00     0      -1
# 2014-11-07 03:20:00     0      -1
# 2014-11-07 03:30:00     0      -1
# 2014-11-07 03:40:00     0      -1

# %%
madrugada[madrugada.TEMP > media].head()
# Out:
# Empty DataFrame
# Columns: [DIRS, DIRR, RAPVIENTO2, RAPRAFAGA2, TEMP, HR, PB, PREC, RADSOL]
# Index: []

# %%
xalapaOb['TEMP'].describe()
# Out:
# count    143.000000
# mean      18.377622
# std        2.711281
# min       15.400000
# 25%       16.350000
# 50%       17.200000
# 75%       20.500000
# max       24.600000
# dtype: float64

# %%
figsize(11.5, 6)
font_size = 20
plt.title('Distribucion de la rapidez del viento', fontsize=font_size)
# plt.ylabel('frecuen',fontsize = font_size)
plt.xlabel('Nudos',fontsize = font_size)
xalapaOb.RAPVIENTO2.hist(bins=6);
