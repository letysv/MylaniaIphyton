# %%
# %run ../talktools.py
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Nixie+One' rel='stylesheet' type='text/css'>
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# #notebook_panel { /* main background */
#     background: rgb(245,245,245);
# }
#
# div.cell { /* set cell width */
#     width: 750px;
# }
#
# div #notebook { /* centre the content */
# ...

# %%
# %%cmd
# !git config --global user.name 'Leticia Sedas'
# !git config --global user.email letysv@gmail.com
# Out:
# Microsoft Windows [Versi�n 6.1.7601]
# Copyright (c) 2009 Microsoft Corporation. Reservados todos los derechos.
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo>!git config --global user.name 'Leticia Sedas'
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo>!git config --global user.email letysv@gmail.com
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo>
# "!git" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.
# "!git" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %%
# %%cmd
# git config --global user.name 'Leticia Sedas'
# git config --global user.email letysv@gmail.com
# Out:
# Microsoft Windows [Versi�n 6.1.7601]
# Copyright (c) 2009 Microsoft Corporation. Reservados todos los derechos.
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo>git config --global user.name 'Leticia Sedas'
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo>git config --global user.email letysv@gmail.com
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo>
# "git" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.
# "git" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %%
# %%cmd
# git config --global core.editor /usr/bin/nano
# git config --global color.ui "auto"
# Out:
# Microsoft Windows [Versi�n 6.1.7601]
# Copyright (c) 2009 Microsoft Corporation. Reservados todos los derechos.
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo>git config --global core.editor /usr/bin/nano
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo>git config --global color.ui "auto"
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo>
# "git" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.
# "git" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %%
# !git
# Out:
# "git" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %%
# %%cmd
# !mkdir -rf gitdemo
# git init gitdemo
# Out:
# Microsoft Windows [Versi�n 6.1.7601]
# Copyright (c) 2009 Microsoft Corporation. Reservados todos los derechos.
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo>!mkdir -rf gitdemo
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo>git init gitdemo
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo>
# "!mkdir" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.
# "git" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %%
# %%cmd
# mkdir -rf gitdemo
# git init gitdemo
# Out:
# Microsoft Windows [Versi�n 6.1.7601]
# Copyright (c) 2009 Microsoft Corporation. Reservados todos los derechos.
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo>mkdir -rf gitdemo
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo>git init gitdemo
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo>
# "git" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %%
# %%cmd
# mkdir -rf gitdemo
# git init gitdemo
# Out:
# Microsoft Windows [Versi�n 6.1.7601]
# Copyright (c) 2009 Microsoft Corporation. Reservados todos los derechos.
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo>mkdir -rf gitdemo
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo>git init gitdemo
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo>
# Ya existe el subdirectorio o el archivo -rf.
# Error mientras se procesaba: -rf.
# Ya existe el subdirectorio o el archivo gitdemo.
# Error mientras se procesaba: gitdemo.
# "git" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %%
# %%cmd
# cd gitdemo
# ls -al
# Out:
# Microsoft Windows [Versi�n 6.1.7601]
# Copyright (c) 2009 Microsoft Corporation. Reservados todos los derechos.
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo>cd gitdemo
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo\gitdemo>ls -al
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo\gitdemo>
# "ls" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %%
# %%cmd
# cd gitdemo
# ls -al .git
# Out:
# Microsoft Windows [Versi�n 6.1.7601]
# Copyright (c) 2009 Microsoft Corporation. Reservados todos los derechos.
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo>cd gitdemo
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo\gitdemo>ls -al .git
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo\gitdemo>
# "ls" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %%
# %%bcmd
# cd gitdemo
# !ls -al .git
# Out:
# ERROR: Cell magic `%%bcmd` not found.

# %%
# %%cmd
# cd gitdemo
# !ls -al .git
# Out:
# Microsoft Windows [Versi�n 6.1.7601]
# Copyright (c) 2009 Microsoft Corporation. Reservados todos los derechos.
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo>cd gitdemo
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo\gitdemo>!ls -al .git
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo\gitdemo>
# "!ls" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %%
# %%cmd
# cd gitdemo/
#
# git commit -a -m"Este archivo refleja el primer compromiso"
# Out:
# Microsoft Windows [Versi�n 6.1.7601]
# Copyright (c) 2009 Microsoft Corporation. Reservados todos los derechos.
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo>cd gitdemo/
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo\gitdemo>
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo\gitdemo>git commit -a -m"Este archivo refleja el primer compromiso"
#
# C:\Users\Lety\Documents\IPython Notebooks\lania.ipython\Dia1\notebooks\gitdemo\gitdemo>
# "git" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.
