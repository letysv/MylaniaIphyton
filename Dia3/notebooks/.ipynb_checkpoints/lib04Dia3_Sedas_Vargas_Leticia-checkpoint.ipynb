# %%
# %run ../talktools.py
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Nixie+One' rel='stylesheet' type='text/css'>
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# #notebook_panel { /* main background */
#     background: rgb(245,245,245);
# }
#
# div.cell { /* set cell width */
#     width: 750px;
# }
#
# div #notebook { /* centre the content */
#     background: #fff; /* white background for content */
#     width: 1000px;
#     margin: auto;
#     padding-left: 0em;
# }
#
# #notebook li { /* More space between bullet points */
# margin-top:0.8em;
# }
#
# /* draw border around running cells */
# div.cell.border-box-sizing.code_cell.running {
#     border: 1px solid #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them*/
# div.cell.code_cell {
#     background-color: rgb(256,256,256);
#     border-radius: 0px;
#     padding: 0.5em;
#     margin-left:1em;
#     margin-top: 1em;
# }
#
# div.text_cell_render{
#     font-family: 'Alegreya Sans' sans-serif;
#     line-height: 140%;
#     font-size: 125%;
#     font-weight: 400;
#     width:600px;
#     margin-left:auto;
#     margin-right:auto;
# }
#
#
# /* Formatting for header cells */
# .text_cell_render h1 {
#     font-family: 'Nixie One', serif;
#     font-style:regular;
#     font-weight: 400;
#     font-size: 45pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.5em;
#     margin-top: 0.5em;
#     display: block;
# }
# .text_cell_render h2 {
#     font-family: 'Nixie One', serif;
#     font-weight: 400;
#     font-size: 30pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.1em;
#     margin-top: 0.3em;
#     display: block;
# }
#
# .text_cell_render h3 {
#     font-family: 'Nixie One', serif;
#     margin-top:16px;
# 	font-size: 22pt;
#     font-weight: 600;
#     margin-bottom: 3px;
#     font-style: regular;
#     color: rgb(102,102,0);
# }
#
# .text_cell_render h4 {    /*Use this for captions*/
#     font-family: 'Nixie One', serif;
#     font-size: 14pt;
#     text-align: center;
#     margin-top: 0em;
#     margin-bottom: 2em;
#     font-style: regular;
# }
#
# .text_cell_render h5 {  /*Use this for small titles*/
#     font-family: 'Nixie One', sans-serif;
#     font-weight: 400;
#     font-size: 16pt;
#     color: rgb(163,0,0);
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.8em;
#     display: block;
# }
#
# .text_cell_render h6 { /*use this for copyright note*/
#     font-family: 'PT Mono', sans-serif;
#     font-weight: 300;
#     font-size: 9pt;
#     line-height: 100%;
#     color: grey;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .CodeMirror{
#         font-family: "PT Mono";
#         font-size: 90%;
# }
#
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"],
#                            equationNumbers: { autoNumber: "AMS", useLabelIds: true}
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %%
file_name = '../files/Sensor_record_20141108_141115_AndroSensor.csv'
sensorData = pd.read_csv(file_name, sep=';', header=1)
sensorData[:10]
# Out:
#    ACCELEROMETER X (m/s²)  ACCELEROMETER Y (m/s²)  ACCELEROMETER Z (m/s²)  \
# 0                 -0.9553                  6.0142                  6.9887
# 1                 -0.3855                  4.2952                  8.2660
# 2                  0.7709                  0.0455                  9.1602
# 3                  0.8523                  1.2857                  9.4128
# 4                  1.2677                  1.1708                  7.7141
# 5                  1.7071                  1.8555                 11.1235
# 6                  1.5814                  2.5163                  9.1518
# 7                  1.2222                  1.7166                  9.1255
# 8                  1.1720                  1.5562                  8.2720
# 9                  2.6085                  2.3236                 10.3645
#
#    GRAVITY X (m/s²)  GRAVITY Y (m/s²)  GRAVITY Z (m/s²)  \
# 0            1.9349            7.2055            6.3646
# 1            2.3434            6.4066            7.0452
# 2            2.8094            2.2039            9.1335
# 3            3.4089            0.9235            9.1486
# 4            2.9591            1.7599            9.1824
# 5            2.5163            1.3947            9.3751
# 6            2.9089            2.3057            9.0770
# 7            0.9641            3.2335            9.2079
# 8            0.8711            2.8123            9.3543
# 9            1.4667            1.8111            9.5257
#
#    LINEAR ACCELERATION X (m/s²)  LINEAR ACCELERATION Y (m/s²)  \
# 0                       -2.8902                       -1.1912
# 1                       -2.7289                       -2.1114
# 2                       -2.6971                       -1.8761
# 3                       -3.0084                        0.3128
# 4                       -1.6914                       -0.5891
# 5                       -0.8093                        0.4609
# 6                       -1.3275                        0.2106
# 7                        0.2581                       -1.5168
# 8                        0.3008                       -1.2561
# 9                        0.5672                       -0.6618
#
#    LINEAR ACCELERATION Z (m/s²)  GYROSCOPE X (rad/s)         ...           \
# 0                        0.6241              -0.3855         ...
# 1                        1.2208              -0.0512         ...
# 2                        2.1002              -0.1830         ...
# 3                        1.2494               0.2342         ...
# 4                       -1.4683               0.1820         ...
# 5                        1.7483              -0.2708         ...
# 6                        0.0748              -0.1103         ...
# 7                       -0.0824              -0.2411         ...
# 8                       -1.0823              -0.4221         ...
# 9                        0.9549              -0.1357         ...
#
#    LOCATION Longitude :   LOCATION Altitude ( m)  LOCATION Speed ( Kmh)  \
# 0              -96.91517                     NaN                    NaN
# 1              -96.91517                     NaN                    NaN
# 2              -96.91517                     NaN                    NaN
# 3              -96.91517                     NaN                    NaN
# 4              -96.91517                     NaN                    NaN
# 5              -96.91517                     NaN                    NaN
# 6              -96.91517                     NaN                    NaN
# 7              -96.91517                     NaN                    NaN
# 8              -96.91517                     NaN                    NaN
# 9              -96.91517                     NaN                    NaN
#
#    LOCATION Accuracy ( m)  Satellites in range  Temperature (F)  Level (%)  \
# 0               164.51613                0 / 3             86.4         90
# 1               164.51613                0 / 3             86.4         90
# 2               164.51613                0 / 9             86.4         90
# 3               164.51613               0 / 10             86.4         90
# 4               164.51613               0 / 10             86.4         90
# 5               164.51613               0 / 10             86.4         90
# 6               164.51613               0 / 10             86.4         90
# 7               164.51613               0 / 10             86.4         90
# 8               164.51613               0 / 10             86.4         90
# 9               164.51613               0 / 12             86.4         90
#
#    Voltage (Volt)  Time since start in ms   YYYY-MO-DD HH-MI-SS_SSS
# 0           4.115                       71  2014-11-08 13:52:55:131
# 1           4.115                      591  2014-11-08 13:52:55:651
# 2           4.115                     1112  2014-11-08 13:52:56:172
# 3           4.115                     1655  2014-11-08 13:52:56:715
# 4           4.115                     2158  2014-11-08 13:52:57:218
# 5           4.115                     2666  2014-11-08 13:52:57:726
# 6           4.115                     3249  2014-11-08 13:52:58:309
# 7           4.115                     3765  2014-11-08 13:52:58:825
# 8           4.115                     4325  2014-11-08 13:52:59:385
# 9           4.115                     4862  2014-11-08 13:52:59:922
#
# [10 rows x 31 columns]

# %%
geodatos = sensorData.iloc[:,20:22]
geodatos[:10]
# Out:
#    LOCATION Latitude :   LOCATION Longitude :
# 0             19.519304              -96.91517
# 1             19.519304              -96.91517
# 2             19.519304              -96.91517
# 3             19.519304              -96.91517
# 4             19.519304              -96.91517
# 5             19.519304              -96.91517
# 6             19.519304              -96.91517
# 7             19.519304              -96.91517
# 8             19.519304              -96.91517
# 9             19.519304              -96.91517

# %%
# %matplotlib inline

# %%
sensorData.plot(legend=False)

# %%
geodatos.keys()
# Out:
# Index([u'LOCATION Latitude : ', u'LOCATION Longitude : '], dtype='object')

# %%
geodatos.keys()[0]
# Out:
# 'LOCATION Latitude : '

# %%
geodatos.plot(x=geodatos.keys()[0], y=geodatos.keys()[1], kind='scatter')

# %%
# !conda install basemap

# %%
from mpl_toolkits.basemap import Basemap
from datetime import datetime

# %%
lats = geodatos.values[:,0]
lons = geodatos.values[:,1]

# %%
m = Basemap(projection='hammer',lon_0=-90)

x, y = m(lons,lats)

m.drawmapboundary(fill_color='#99ffff')
m.fillcontinents(color='#cc9966',lake_color='#99ffff')
m.scatter(x,y,24,marker='o',color='k')
plt.text(x[-1],y[-1],'LANIA',color='b');

# %%
map = Basemap(projection='mill',lon_0=-90)
# plot coastlines, draw label meridians and parallels.
map.drawcoastlines()
map.drawparallels(np.arange(-90,90,30),labels=[1,0,0,0])
map.drawmeridians(np.arange(map.lonmin,map.lonmax+30,60),labels=[0,0,0,1])
# fill continents 'coral' (with zorder=0), color wet areas 'aqua'
map.drawmapboundary(fill_color='#99ffff')
map.fillcontinents(color='coral',lake_color='#99ffff')
x, y = map(lons,lats)
map.scatter(x,y,24,marker='o', color='b')
plt.text(x[-1],y[-1],'LANIA',color='b');

# %%
map = Basemap(projection='mill',lon_0=-90)
# plot coastlines, draw label meridians and parallels.
map.drawcoastlines()
map.drawparallels(np.arange(-90,90,30),labels=[1,0,0,0])
map.drawmeridians(np.arange(map.lonmin,map.lonmax+30,60),labels=[0,0,0,1])
# fill continents 'coral' (with zorder=0), color wet areas 'aqua'
map.drawmapboundary(fill_color='#99ffff')
map.fillcontinents(color='coral',lake_color='#99ffff')
x, y = map(lons,lats)
map.scatter(x,y,24,marker='o', color='b')
plt.text(x[-1],y[-1],'LANIA',color='b');
date = datetime.utcnow()
#date=datetime.utcfromtimestamp(timeStamp.values[-1])
CS=map.nightshade(date)
plt.title('Day/Night Map for %s (UTC)' % date.strftime("%d %b %Y %H:%M:%S"));
